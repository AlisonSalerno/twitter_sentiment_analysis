# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)
import numpy as np
import warnings
warnings.filterwarnings('ignore')

import re

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.stem import PorterStemmer

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import MultinomialNB

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score


from wordcloud import WordCloud, STOPWORDS

import string
from matplotlib import style
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#reading in 2020 tweets for nuclear energy with labels attached
df = pd.read_csv('tweets_2020_labeled.csv',index_col=0)

# %%
#Create stopwords list

stopwords_list = stopwords.words('english')
stopwords_list += ['nuclear','energy','…','nuclearenergy','’','核エネルギーの潜在的な危険性は、いくら強調してもし過ぎるということはない。']

# %%
X = df['tweet']
y = df['labeled_tweet']

# %%
#there are more positive than negative but majority is neutral
plt.style.use('seaborn-talk')
plt.figure() 
fig1 = y.value_counts().plot(kind='bar', figsize=(12,8))
plt.title('Label Distribution')
fig1.set(xticklabels=['Neutral', 'Positive', 'Negative'])
plt.xticks(rotation=0)
plt.xlabel('Labels')
plt.ylabel('Number of Tweets')
plt.show()

# %%
y.value_counts(normalize=True)
# Out:
# neu    0.775000
# pos    0.157667
# neg    0.067333
# Name: labeled_tweet, dtype: float64

# %% [markdown]
# ## TF-IDF Vectorizer process for classification

# %%
#function to remove punctuation and non-alphabetical characters
def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    #text = text.lower()
    text = re.sub('\[.*?\]', ' ', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', ' ', text)
    text = re.sub('\n', ' ', text)
    text = re.sub('  ', ' ', text)
    text = re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
    #text = re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', '', text)
    return text

#test = clean_text_round1(tweet_df['tweet'][24])
round1 = lambda x: clean_text_round1(x)
X_fake = pd.DataFrame(X.apply(round1))

# %%
X = X_fake['tweet']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=20)

tfidf = TfidfVectorizer(stop_words = stopwords_list)
tfidf_data_train = tfidf.fit_transform(X_train)
tfidf_data_test = tfidf.transform(X_test)
#tfidf_data_train

# %%
tfidf_data_train.shape
# Out:
# (2250, 8037)

# %% [markdown]
# ### Dummy Classifier

# %%
from sklearn.dummy import DummyClassifier

# %%
dc_classifier = DummyClassifier(strategy='most_frequent')

dc_classifier.fit(tfidf_data_train, y_train)

dc_train_preds = dc_classifier.predict(tfidf_data_train)
dc_test_preds = dc_classifier.predict(tfidf_data_test)

# %%
dc_train_score = accuracy_score(y_train, dc_train_preds)
dc_test_score = accuracy_score(y_test, dc_test_preds)

print('Dummy with TF-IDF')
print("Training Accuracy: {:.4}".format(dc_train_score))
print("Testing Accuracy: {:.4}".format(dc_test_score))
# Out:
# Dummy with TF-IDF
# Training Accuracy: 0.7742
# Testing Accuracy: 0.7773

# %% [markdown]
# ### Models - NB & RF

# %%
#Naiive Bayes Model

nb_classifier = MultinomialNB()

nb_classifier.fit(tfidf_data_train, y_train)

nb_train_preds = nb_classifier.predict(tfidf_data_train)
nb_test_preds = nb_classifier.predict(tfidf_data_test)

# %%
nb_train_score = accuracy_score(y_train, nb_train_preds)
nb_test_score = accuracy_score(y_test, nb_test_preds)

print('Naiive-Bayes with TF-IDF')
print("Training Accuracy: {:.4}".format(nb_train_score))
print("Testing Accuracy: {:.4}".format(nb_test_score))
# Out:
# Naiive-Bayes with TF-IDF
# Training Accuracy: 0.7929
# Testing Accuracy: 0.7853

# %%
#Random Forest Model

rf_classifier = RandomForestClassifier(n_estimators=500, random_state=0, class_weight='balanced')

rf_classifier.fit(tfidf_data_train, y_train)

rf_test_preds = rf_classifier.predict(tfidf_data_test)
rf_train_preds = rf_classifier.predict(tfidf_data_train)

# %%
rf_acc_score_train = accuracy_score(y_train, rf_train_preds)
rf_acc_score = accuracy_score(y_test, rf_test_preds)

print('Random Forest with TF-IDF')
print("Training Accuracy: {:.4}".format(rf_acc_score_train))
print("Testing Accuracy: {:.4}".format(rf_acc_score))
# Out:
# Random Forest with TF-IDF
# Training Accuracy: 0.9991
# Testing Accuracy: 0.78

# %%
#feature importance scores
#Decision tree algorithms like classification offer importance scores based on the reduction in the criterion used to select split points, like Gini or entropy.
feat_importanceDF_rfc_2 = pd.DataFrame(rf_classifier.feature_importances_, index=tfidf.vocabulary_)
feat_importanceDF_rfc_2.sort_values(by=0,ascending=False).head(15)
# Out:
#                                 0
# years                    0.016471
# avstå                    0.014785
# angela                   0.011872
# imp                      0.010523
# expanding                0.009393
# laptop                   0.009299
# pictwittercomvkzlcwpgzh  0.008645
# ahero                    0.008049
# worrisome                0.007889
# wilmington               0.007579
# hates                    0.007496
# chronological            0.007216
# inefficiency             0.007053
# availability             0.006928
# exciting                 0.006725

# %%
#plot top 5 features for the RFC
feat_importances_2 = pd.Series(rf_classifier.feature_importances_,index=tfidf.vocabulary_)
feat_importances_2.nlargest(15).sort_values().plot(kind='barh')
plt.title("Top 15 Feature Importance - RFC")
plt.xlabel('Relative Importance')
plt.ylabel('Tokens')
plt.show()

# %%
#number of features
len(tfidf.vocabulary_)
# Out:
# 7702

# %%
tfidf.get_feature_names()
# Out:
# ['aa',
#  'aalto',
#  'aarogyasetuapp',
#  'ab',
#  'abandon',
#  'abandoning',
#  'abandonment',
#  'abc',
#  'abeninforma',
#  'aberration',
#  'ability',
#  'able',
#  'ableg',
#  'aboilsands',
#  'abolished',
#  'abolition',
#  'abolitionism',
#  'abortion',
#  'abq',
#  'abqjournal',
#  'abroad',
#  'absence',
#  'absolute',
#  'absolutely',
#  'absorbed',
#  'absurdist',
#  'abt',
#  'abudhabi',
#  'abundance',
#  'abundant',
#  'abundantly',
#  'abuse',
#  'academia',
#  'academic',
#  'academy',
#  'accelerate',
#  'accelerated',
#  'accelerating',
#  'accelerator',
#  'accept',
#  'acceptable',
#  'access',
#  'accident',
#  'accidental',
#  'accommodate',
#  'accord',
#  'according',
#  'account',
#  'accumulating',
#  'accurate',
#  'accurately',
#  'accuse',
#  'accused',
#  'acehoffman',
#  'acglobalenergy',
#  'acglobalenergys',
#  'achievable',
#  'achieve',
#  'achieved',
#  'achievement',
#  'achieves',
#  'achieving',
#  'acid',
#  'acknowledge',
#  'acolyte',
#  'acquire',
#  'acquires',
#  'acquisition',
#  'acronym',
#  'across',
#  'act',
#  'acting',
#  'action',
#  'activate',
#  'active',
#  'actively',
#  'activism',
#  'activist',
#  'activity',
#  'actual',
#  'actualidadrt',
#  'actuality',
#  'actually',
#  'actuar',
#  'acuerdos',
#  'ada',
#  'adam',
#  'adamusdfc',
#  'adani',
#  'adapt',
#  'add',
#  'added',
#  'addiction',
#  'adding',
#  'addition',
#  'additional',
#  'additionally',
#  'address',
#  'addressing',
#  'aderemi',
#  'adjust',
#  'admin',
#  'administration',
#  'admired',
#  'adoption',
#  'adopts',
#  'adoration',
#  'aduhhhh',
#  'advance',
#  'advanceausthome',
#  'advanced',
#  'advancednuclear',
#  'advancement',
#  'advancing',
#  'advantage',
#  'adviser',
#  'advisor',
#  'advocate',
#  'advocates',
#  'advocating',
#  'aecleacl',
#  'aerei',
#  'aerospace',
#  'affect',
#  'affected',
#  'affecting',
#  'afford',
#  'affordable',
#  'affordably',
#  'aflivetweet',
#  'africa',
#  'african',
#  'afterlife',
#  'afternoon',
#  'age',
#  'agence',
#  'agency',
#  'agencyenergy',
#  'agenda',
#  'agent',
#  'agneta',
#  'ago',
#  'agodumb',
#  'agree',
#  'agreed',
#  'agreement',
#  'agrees',
#  'agriculture',
#  'agroécologie',
#  'agw',
#  'ah',
#  'aha',
#  'ahead',
#  'ahero',
#  'ahmadu',
#  'ai',
#  'aid',
#  'aim',
#  'aimed',
#  'aiming',
#  'ainsi',
#  'air',
#  'aircraft',
#  'airliner',
#  'airplane',
#  'ajay',
#  'aka',
#  'akon',
#  'aku',
#  'al',
#  'alarmed',
#  'alarmism',
#  'alastair',
#  'albert',
#  'alberta',
#  'albertanuclear',
#  'alberteinstein',
#  'alcoholic',
#  'alevel',
#  'ali',
#  'aliados',
#  'alien',
#  'alive',
#  'alland',
#  'alleen',
#  'allen',
#  'alliance',
#  'allied',
#  'allocates',
#  'allots',
#  'allow',
#  'allowed',
#  'allowing',
#  'allows',
#  'ally',
#  'almost',
#  'aloksharmardg',
#  'alone',
#  'along',
#  'alongside',
#  'alot',
#  'already',
#  'also',
#  'alternative',
#  'although',
#  'always',
#  'ama',
#  'amano',
#  'amar',
#  'amazement',
#  'amazing',
#  'amazon',
#  'amb',
#  'ambassador',
#  'ambition',
#  'ambitious',
#  'amenazas',
#  'amendment',
#  'america',
#  'american',
#  'ames',
#  'amid',
#  'amidst',
#  'amjoy',
#  'among',
#  'amory',
#  'amount',
#  'amounted',
#  'amplifies',
#  'amundson',
#  'an',
#  'analogy',
#  'analysis',
#  'analyst',
#  'analytical',
#  'analytics',
#  'anathemizes',
#  'ancient',
#  'andnotor',
#  'andreatoyias',
#  'andrew',
#  'andrewyang',
#  'andré',
#  'ang',
#  'angan',
#  'angela',
#  'angelou',
#  'angst',
#  'animal',
#  'animation',
#  'anime',
#  'ann',
#  'annette',
#  'anni',
#  'announce',
#  'announced',
#  'announcement',
#  'announces',
#  'annual',
#  'annually',
#  'annukkavainio',
#  'another',
#  'ansannual',
#  'ansorg',
#  'answer',
#  'answered',
#  'answeri',
#  'answeryes',
#  'ansymg',
#  'anthropogenic',
#  'anti',
#  'antibiotic',
#  'anticorporate',
#  'anticorruption',
#  'antiduplicative',
#  'antiformulafeeding',
#  'antigmo',
#  'antigravity',
#  'antimatter',
#  'antinuclear',
#  'antinuclearenergy',
#  'antiquated',
#  'antiracism',
#  'antiretroviral',
#  'antiscience',
#  'antistudent',
#  'antitrust',
#  'antiwealth',
#  'anybody',
#  'anyone',
#  'anything',
#  'anythingbecause',
#  'anyway',
#  'aoc',
#  'aocs',
#  'aomoris',
#  'apa',
#  'apakah',
#  'apparently',
#  'appear',
#  'appelez',
#  'appetite',
#  'applaud',
#  'applauds',
#  'applesupport',
#  'applicable',
#  'application',
#  'applied',
#  'appliedenergy',
#  'applies',
#  'applus',
#  'apply',
#  'applying',
#  'appointed',
#  'approach',
#  'approval',
#  'approvement',
#  'approves',
#  'appy',
#  'april',
#  'aps',
#  'apsenergia',
#  'arab',
#  'arabia',
#  'arabian',
#  'arbitrary',
#  'arbor',
#  'archangel',
#  'architech',
#  'architecture',
#  'arctic',
#  'ard',
#  'ardp',
#  'area',
#  'arent',
#  'areva',
#  'argonne',
#  'argue',
#  'argues',
#  'argument',
#  'argumentation',
#  'arm',
#  'armes',
#  'armored',
#  'army',
#  'armywarcollege',
#  'around',
#  'aroused',
#  'arpae',
#  'arrangement',
#  'array',
#  'arrogance',
#  'arsenal',
#  'art',
#  'artcles',
#  'article',
#  'articolo',
#  'artificial',
#  'artificially',
#  'artist',
#  'artistic',
#  'artwork',
#  'as',
#  'asamoh',
#  'asanteshezi',
#  'asap',
#  'ascertained',
#  'ascope',
#  'asean',
#  'ased',
#  'ashamed',
#  'asia',
#  'asian',
#  'aside',
#  'asinine',
#  'asiyifuni',
#  'ask',
#  'asked',
#  'asking',
#  'askliberasi',
#  'asks',
#  'aspect',
#  'ass',
#  'assertion',
#  'assessing',
#  'assessment',
#  'asset',
#  'assignment',
#  'assistance',
#  'assistant',
#  'associated',
#  'association',
#  'assume',
#  'assured',
#  'assystem',
#  'astounding',
#  'astronomical',
#  'asx',
#  'atau',
#  'atlantic',
#  'atlanticcouncil',
#  'atm',
#  'atmosphere',
#  'atmospheric',
#  'atom',
#  'atombomb',
#  'atomenergie',
#  'atomexit',
#  'atomic',
#  'atomica',
#  'atomicnuclei',
#  'atomicrod',
#  'atomics',
#  'atomiс',
#  'atomowej',
#  'aton',
#  'atsocialmediauk',
#  'att',
#  'attache',
#  'attack',
#  'attempt',
#  'attend',
#  'attending',
#  'attention',
#  'attitude',
#  'attitudinal',
#  'attraction',
#  'attractiveness',
#  'attribute',
#  'au',
#  'aucune',
#  'audiolibro',
#  'audioteka',
#  'august',
#  'augustseptember',
#  'aunque',
#  'auspol',
#  'aussieed',
#  'aust',
#  'austlook',
#  'australia',
#  'australian',
#  'australianlabor',
#  'austria',
#  'author',
#  'authority',
#  'authorization',
#  'auto',
#  'automating',
#  'automation',
#  'automobile',
#  'av',
#  'availability',
#  'available',
#  'avancée',
#  'avenir',
#  'average',
#  'averse',
#  'avez',
#  'aviation',
#  'avoid',
#  'avoided',
#  'avoiding',
#  'avoids',
#  'avstå',
#  'avuto',
#  'awaited',
#  'award',
#  'awarded',
#  'awardwinning',
#  'aware',
#  'awareness',
#  'awash',
#  'away',
#  'awesome',
#  'awolowo',
#  'ayrshire',
#  'ba',
#  'babiš',
#  'baby',
#  'back',
#  'backed',
#  'backfired',
#  'background',
#  'backlash',
#  'backlog',
#  'backup',
#  'backwards',
#  'bad',
#  'badly',
#  'bag',
#  'baggage',
#  'baghjanfire',
#  'baghjanoilfield',
#  'bai',
#  'bailout',
#  'bailouts',
#  'baiqlah',
#  'bait',
#  'balakovo',
#  'balance',
#  'balancing',
#  'baldesarra',
#  'balm',
#  'baloziyatani',
#  'baltic',
#  'ban',
#  'bangladesh',
#  'bank',
#  'bankingenergy',
#  'banned',
#  'banning',
#  'bannuclearplant',
#  'bar',
#  'barack',
#  'barackobama',
#  'barackobamaera',
#  'barakah',
#  'barakahnuclearpowerplant',
#  'baranwal',
#  'barkla',
#  'barometer',
#  'base',
#  'based',
#  'baseload',
#  'basic',
#  'basically',
#  'basin',
#  'basket',
#  'bastide',
#  'battered',
#  'battery',
#  'battle',
#  'baud',
#  'bbc',
#  'bbva',
#  'bc',
#  'beat',
#  'beause',
#  'beautiful',
#  'beauty',
#  'beck',
#  'become',
#  'becomes',
#  'becoming',
#  'becuz',
#  'bed',
#  'beef',
#  'beg',
#  'began',
#  'beggar',
#  'begin',
#  'beginner',
#  'beginning',
#  'begituuu',
#  'begun',
#  'behalf',
#  'behavior',
#  'behind',
#  'beijing',
#  'being',
#  'beisgovuk',
#  'belarus',
#  'belgian',
#  'belgium',
#  'belief',
#  'believe',
#  'believing',
#  'bellevillesurloire',
#  'bello',
#  'belong',
#  'belongs',
#  'belt',
#  'bend',
#  'benefit',
#  'benefited',
#  'bengazzi',
#  'bengingaz',
#  'benieuwd',
#  'benjindolo',
#  'bentar',
#  'bep',
#  'berapi',
#  'berger',
#  'berkeleylab',
#  'berman',
#  'bernie',
#  'beschäftigten',
#  'besides',
#  'best',
#  'bet',
#  'bethany',
#  'bethanygoldblum',
#  'better',
#  'betternormal',
#  'betting',
#  'betul',
#  'bevroren',
#  'beware',
#  'beyond',
#  'beyondnukesint',
#  'bezpečnost',
#  'bharat',
#  'bhi',
#  'bhist',
#  'biden',
#  'big',
#  'bigger',
#  'biggest',
#  'bigoted',
#  'bigotry',
#  'bike',
#  'bila',
#  'bilang',
#  'bilfinger',
#  'bilfingers',
#  'bilibino',
#  'bill',
#  'billgates',
#  'billion',
#  'bin',
#  'bind',
#  'binding',
#  'bingo',
#  'biofuels',
#  'biological',
#  'biomass',
#  'biomassa',
#  'biomassacentrale',
#  'biomassfired',
#  'biosecurity',
#  'biotechnology',
#  'bipartisan',
#  'bipoc',
#  'bird',
#  'birth',
#  'birthplace',
#  'bit',
#  'bitch',
#  'bitching',
#  'bitchslapped',
#  'bitcoin',
#  'bitcoiners',
#  'bitcoins',
#  'biz',
#  'bjp',
#  'bjps',
#  'black',
#  'blacklist',
#  'blacklivesmatter',
#  'blah',
#  'blame',
#  'blank',
#  'blast',
#  'blatant',
#  'blatantly',
#  'blender',
#  'bless',
#  'blinded',
#  'blink',
#  'blm',
#  'blobby',
#  'block',
#  'blockchain',
#  'blocked',
#  'blog',
#  'bloke',
#  'blood',
#  'bloody',
#  'bloomberg',
#  'blow',
#  'blowing',
#  'blue',
#  'bluman',
#  'blurring',
#  'blvcklogan',
#  'bn',
#  'bo',
#  'board',
#  'boardroom',
#  'boat',
#  'bobbyramakant',
#  'bode',
#  'bodrov',
#  'body',
#  'bohunice',
#  'boil',
#  'boiling',
#  'boilingfrog',
#  'bold',
#  'bolivia',
#  'bolt',
#  'bomb',
#  'bombahan',
#  'bombarded',
#  'bombed',
#  'bonus',
#  'booby',
#  'book',
#  'boom',
#  'boomer',
#  'boost',
#  'boosting',
#  'boot',
#  'border',
#  'born',
#  'boseeinstein',
#  'bosnian',
#  'boson',
#  'boston',
#  'bothered',
#  'bottle',
#  'bought',
#  'bound',
#  'boundary',
#  'bouw',
#  'box',
#  'boy',
#  'boycott',
#  'bp',
#  'bpplc',
#  'brain',
#  'brainer',
#  'brainwashing',
#  'branching',
#  'brave',
#  'bravo',
#  'brazil',
#  'brazilian',
#  'breadlsdnuclear',
#  'break',
#  'breakthrough',
#  'breakthroughshow',
#  'breath',
#  'breathe',
#  'breed',
#  'breeder',
#  'breeding',
#  'breeze',
#  'brexit',
#  'bribe',
#  'bridgwater',
#  'brief',
#  'brien',
#  'bright',
#  'brilliant',
#  'bring',
#  'bringing',
#  'brings',
#  'brioche',
#  'britain',
#  'british',
#  'bro',
#  'broad',
#  'broadband',
#  'broadcasting',
#  'broaden',
#  'broader',
#  'broke',
#  'broken',
#  'brought',
#  'brouillette',
#  'bruce',
#  'brucepower',
#  'brush',
#  'brutality',
#  'bryce',
#  'btw',
#  'bucharest',
#  'budget',
#  'budgetary',
#  'bugger',
#  'build',
#  'building',
#  'buildnew',
#  'buildup',
#  'built',
#  'bukak',
#  'bulb',
#  'bulgaria',
#  'bulgarian',
#  'bull',
#  'bullied',
#  'bullish',
#  'bullshit',
#  'bully',
#  'bumi',
#  'bump',
#  'bunch',
#  'bungeliveke',
#  'bunny',
#  'bure',
#  'bureau',
#  'burn',
#  'burned',
#  'burning',
#  'bury',
#  'business',
#  'businesskt',
#  'businessnews',
#  'bust',
#  'busting',
#  'busy',
#  'but',
#  'butthurt',
#  'button',
#  'buy',
#  'buying',
#  'bwxtech',
#  'bynuclear',
#  'bypassed',
#  'byproduct',
#  'bürger',
#  'cabal',
#  'cabinet',
#  'cable',
#  'cabling',
#  'cadre',
#  'caducados',
#  'cafe',
#  'cagr',
#  'caldicott',
#  'caldicotts',
#  'calendar',
#  'california',
#  'call',
#  'callawaynucleargeneratingstation',
#  'called',
#  'calling',
#  'calming',
#  'cambridge',
#  'came',
#  'camerasare',
#  'campaign',
#  'canada',
#  'canadamoving',
#  'canadaus',
#  'canadian',
#  'canberratimes',
#  'cancellation',
#  'cancelled',
#  'cancer',
#  'cancerous',
#  'candidate',
#  'candle',
#  'candu',
#  'cant',
#  'canus',
#  'caorso',
#  'capability',
#  'capable',
#  'capacity',
#  'cape',
#  'capitalism',
#  'capitalist',
#  'capsindia',
#  'capture',
#  'captured',
#  'capturer',
#  'car',
#  'carbon',
#  'carbonconstrained',
#  'carbone',
#  'carbonfree',
#  'carbonfreeelectricity',
#  'carbonneutral',
#  'card',
#  'cardana',
#  'care',
#  'cared',
#  'career',
#  'careful',
#  'carefulhurt',
#  'carefully',
#  'cargo',
#  'caribbean',
#  'caring',
#  'carl',
#  'carlsbad',
#  'carlson',
#  'carry',
#  'cartel',
#  'carter',
#  'case',
#  'cash',
#  'cast',
#  'castley',
#  'casually',
#  'cat',
#  'catalina',
#  'catalyst',
#  'catastrophe',
#  'catastrophic',
#  'catastrophically',
#  'catch',
#  'categorical',
#  'cathmckenna',
#  'cation',
#  'caucus',
#  'caught',
#  'cause',
#  'caused',
#  'causing',
#  'caveat',
#  'cbc',
#  'cbinsights',
#  'cc',
#  'ccp',
#  'ccurrentargus',
#  'cdenv',
#  'cdndimension',
#  'cdnpoli',
#  'cec',
#  'cede',
#  'ceded',
#  'cegelec',
#  'celebrate',
#  'celebrates',
#  'cell',
#  'celtic',
#  'cement',
#  'censorship',
#  'center',
#  'centerleft',
#  'central',
#  'centrale',
#  'centrales',
#  'centre',
#  'centreval',
#  'centrist',
#  'century',
#  'cenv',
#  'ceo',
#  'ceramic',
#  'cercle',
#  'ceremony',
#  'cern',
#  'cernavoda',
#  'certain',
#  'certainly',
#  'certification',
#  'cest',
#  'cette',
#  'cfe',
#  'cgn',
#  'chaek',
#  'chahiye',
#  'chain',
#  'chained',
#  'chair',
#  'chairman',
#  'chal',
#  'chalamet',
#  'chalk',
#  'challenge',
#  'challenged',
#  'chalti',
#  'champagne',
#  'champion',
#  'chance',
#  'chanel',
#  'change',
#  'changed',
#  'changement',
#  'changing',
#  'channel',
#  'channeling',
#  'chantajes',
#  'chantal',
#  'chaos',
#  'chapeau',
#  'chapman',
#  'chapter',
#  'character',
#  'charbons',
#  'charge',
#  'charity',
#  'charles',
#  'charlie',
#  'charmigt',
#  'chart',
#  'charz',
#  'chat',
#  'che',
#  'cheap',
#  'cheaper',
#  'cheapest',
#  'check',
#  'checked',
#  'cheeky',
#  'chef',
#  'chemical',
#  'chemistry',
#  'chemo',
#  'chernobyl',
#  'cheronbyl',
#  'chest',
#  'chick',
#  'chicken',
#  'chief',
#  ...]

# %%
from sklearn.svm import LinearSVC
import matplotlib.pyplot as plt
def plot_coefficients(classifier, feature_names, top_features=20):
    coef = classifier.coef_.ravel()
    top_positive_coefficients = np.argsort(coef)[-top_features:]
    top_negative_coefficients = np.argsort(coef)[:top_features]
    top_coefficients = np.hstack([top_negative_coefficients, top_positive_coefficients])
 # create plot
    plt.figure(figsize=(15, 5))
    colors = ['red' if c < 0 else 'blue' for c in coef[top_coefficients]]
    plt.bar(np.arange(2 * top_features), coef[top_coefficients], color=colors)
    feature_names = np.array(feature_names)
    plt.xticks(np.arange(1,1+2*top_features),feature_names[top_coefficients], rotation=60)
    plt.show()
#cv = CountVectorizer()
#cv.fit(data)
#print len(cv.vocabulary_)
#print cv.get_feature_names()
#X_train = cv.transform(data)

svm = LinearSVC(class_weight='balanced')
svm.fit(tfidf_data_train, y_train)
plot_coefficients(svm, tfidf.get_feature_names())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-65-5f194456164f> in <module>
#      21 svm = LinearSVC(class_weight='balanced')
#      22 svm.fit(tfidf_data_train, y_train)
# ---> 23 plot_coefficients(svm, tfidf.get_feature_names())
#
# <ipython-input-65-5f194456164f> in plot_coefficients(classifier, feature_names, top_features)
#      11     plt.bar(np.arange(2 * top_features), coef[top_coefficients], color=colors)
#      12     feature_names = np.array(feature_names)
# ---> 13     plt.xticks(np.arange(1,1+2*top_features),feature_names[top_coefficients], rotation=60)
#      14     plt.show()
#      15 #cv = CountVectorizer()
#
# IndexError: index 15733 is out of bounds for axis 0 with size 7702

# %%
svm.coef_
# Out:
# array([[ 0.        , -0.04920694, -0.05649543, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.05554942, -0.26407844,  0.05445114, ...,  0.02102912,
#          0.02102912,  0.02102912],
#        [-0.08492157,  0.36224067, -0.05392454, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
svm_test_preds = svm.predict(tfidf_data_test)
svm_train_preds = svm.predict(tfidf_data_train)

svm_acc_score_train = accuracy_score(y_train, svm_train_preds)
svm_acc_score = accuracy_score(y_test, svm_test_preds)

print('SVM with TF-IDF')
print("Training Accuracy: {:.4}".format(svm_acc_score_train))
print("Testing Accuracy: {:.4}".format(svm_acc_score))
# Out:
# SVM with TF-IDF
# Training Accuracy: 0.9924
# Testing Accuracy: 0.8213

# %% [markdown]
# ### Confusion Matrix

# %%
#confusion matrix on train set
sns.set()


mat2 = confusion_matrix(y_train, rf_train_preds)
sns.heatmap(mat2.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=['Negative', 'Neutral', 'Positive'], yticklabels=['Negative', 'Neutral', 'Positive'])
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#confusion matrix on test set
sns.set()


mat = confusion_matrix(y_test, rf_test_preds)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=['Negative', 'Neutral', 'Positive'], yticklabels=['Negative', 'Neutral', 'Positive'])
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
print("Precision Score : ",precision_score(y_test, rf_test_preds, 
                                           average='micro'))
print("Recall Score : ",recall_score(y_test, rf_test_preds, 
                                           average='micro'))
# Out:
# Precision Score :  0.78
# Recall Score :  0.78

# %% [markdown]
# ### Testing Model with Emotions About Nuclear Energy dataset from CROWDFLOWER

# %%
df_crowdflower = pd.read_csv('sentiment_nuclear_power.csv', encoding= 'unicode_escape')

# %%
df_crowdflower['sentiment'].replace({'Neutral / author is just sharing information': 'neu', 
                                     'Negative': 'neg', 
                                     'Positive': 'pos',
                                     'Tweet NOT related to nuclear energy': 'neu'}, inplace=True)

# %%
X_cf = df_crowdflower['tweet_text']
y_cf = df_crowdflower['sentiment']

# %%
y_cf.value_counts(normalize=True)
# Out:
# neu    0.847368
# neg    0.100000
# pos    0.052632
# Name: sentiment, dtype: float64

# %%
X_cf_fake = pd.DataFrame(X_cf.apply(round1))
X_cf = X_cf_fake['tweet_text']



tfidf_cf = tfidf.transform(X_cf)

# %%
tfidf_cf
# Out:
# <190x8037 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1545 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Running the Model

# %%
rf_cf = rf_classifier.predict(tfidf_cf)

rf_cf_score = accuracy_score(y_cf, rf_cf)
print('Random Forest with TF-IDF using crowdflower data')
print("Accuracy: {:.4}".format(rf_cf_score))
# Out:
# Random Forest with TF-IDF using crowdflower data
# Accuracy: 0.6684

# %%
#Confusion Matrix on cf

sns.set()


mat3 = confusion_matrix(y_cf, rf_cf)
sns.heatmap(mat3.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=['Negative', 'Neutral', 'Positive'], yticklabels=['Negative', 'Neutral', 'Positive'])
plt.xlabel('true label')
plt.ylabel('predicted label');

# %% [markdown]
# ## With Lemmatizer

# %%
#reading in 2020 tweets for nuclear energy with labels attached
df_lem = pd.read_csv('tweets_2020_labeled.csv',index_col=0)

# %%
#function to remove punctuation and non-alphabetical characters
def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?\]', ' ', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', ' ', text)
    text = re.sub('\n', ' ', text)
    text = re.sub('  ', ' ', text)
    text = re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
    #text = re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', '', text)
    return text

#test = clean_text_round1(tweet_df['tweet'][24])
round1 = lambda x: clean_text_round1(x)
df_lem.tweet = pd.DataFrame(df_lem.tweet.apply(round1))

# %%
def tokenize(text):
    text = [word_tokenize(x) for x in text]
    return text

df_lem.tweet = tokenize(df_lem.tweet)

# %%
stopwords_list = stopwords.words('english')
stopwords_list += ['nuclear','energy','…','nuclearenergy','’','核エネルギーの潜在的な危険性は、いくら強調してもし過ぎるということはない。']
df_lem.tweet = df_lem['tweet'].apply(lambda x: [item for item in x if item not in stopwords_list])

# %%
p_data =df_lem['tweet']

# %%
from nltk.stem import WordNetLemmatizer 
  
lemmatizer = WordNetLemmatizer()

# %%
# creating a list with all lemmatized outputs
lemmatized_output = []

for listy in p_data:
    lemmed = ' '.join([lemmatizer.lemmatize(w) for w in listy])
    lemmatized_output.append(lemmed)

# %%
X_lem = lemmatized_output
# [' '.join(d) for d in processed_data]

y_lem = df_lem['labeled_tweet']
# X[3]

# %%
X_train_lem, X_test_lem, y_train_lem, y_test_lem = train_test_split(X_lem, y_lem, test_size=0.20, random_state=1)
tfidf = TfidfVectorizer()

tfidf_data_train_lem = tfidf.fit_transform(X_train_lem)
tfidf_data_test_lem = tfidf.transform(X_test_lem)

#tfidf_data_train_lem

# %%
#rf

rf_classifier_lem = RandomForestClassifier(n_estimators=100, random_state=0, class_weight = 'balanced')

rf_classifier_lem.fit(tfidf_data_train_lem, y_train_lem)

rf_test_preds_lem = rf_classifier_lem.predict(tfidf_data_test_lem)
rf_train_preds_lem = rf_classifier_lem.predict(tfidf_data_train_lem)

rf_acc_score_lem = accuracy_score(y_test_lem, rf_test_preds_lem)
rf_train_score_lem = accuracy_score(y_train_lem, rf_train_preds_lem)
print('Random Forest with Lemmatization Features')
print("Training Accuracy: {:.4}".format(rf_train_score_lem))
print("Testing Accuracy: {:.4}".format(rf_acc_score_lem))
# Out:
# Random Forest with Lemmatization Features
# Training Accuracy: 0.9975
# Testing Accuracy: 0.7733
